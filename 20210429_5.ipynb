# %%
#091
inventory = {
    "메로나":[300,20],
    "비비빅":[400,3],
    "죠스바":[250,100]
}

# %%
#092
print("{}원".format(inventory["메로나"][0]))
# Out:
# 300원

# %%
#093
print("{}개".format(inventory["메로나"][1]))
# Out:
# 20원

# %%
#094
inventory["월드콘"]=[500,7]

print(inventory)
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %%
#095
icecream={'탱크보이':1200, '폴라포':1200,'빵빠레':1800,'월드콘':1500,'메로나':1000}
icecream.keys()
# Out:
# dict_keys(['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나'])

# %%
#096
icecream={'탱크보이':1200, '폴라포':1200,'빵빠레':1800,'월드콘':1500,'메로나':1000}
icecream.values()
# Out:
# dict_values([1200, 1200, 1800, 1500, 1000])

# %%
#097
sum(icecream.values())
# Out:
# 6700

# %%
#098
new_product={'팥빙수':2700,'아맛나':1000}
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %%
#099
keys=("apple","pear","peach")
vals=(300,250,400)
result = dict(zip(keys,vals))
print(result)
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %%
#100
date=['09/05','09/06','09/07','09/08','09/09']
close_price = [10500, 10300, 10100, 10800, 11000]
close_table=dict(zip(date,close_price))
print(close_table)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %%
#151
lista=[3,-20,-3,44]

for i in range(len(lista)):
  if lista[i]<0:
    print(lista[i])
# Out:
# -20
# -3

# %%
#152
listb=[3,100,23,44]

for i in range(len(listb)):
  if (listb[i]%3)==0:
    print(listb[i])
# Out:
# 3

# %%
#153
listc=[13,21,12,14,30,18]

for i in range(len(listc)):
  if (listc[i]<20) and (listc[i]%3==0):
    print(listc[i])
# Out:
# 12
# 18

# %%
#154
listd=["I","study","python","language","!"]


for i in range(len(listd)):
  if len(listd[i])>=3:
    print(listd[i])
# Out:
# study
# python
# language

# %%
#155
listal=["A","b","c","D"]

for i in range(len(listal)):
  if listal[i].isupper():
    print(listal[i])
# Out:
# A
# D

# %%
#156
listal=["A","b","c","D"]

for i in range(len(listal)):
  if listal[i].islower():
    print(listal[i])
# Out:
# b
# c

# %%
#157 
listan = ['dog','cat','parrot']

for i in listan:
  print(i[0].upper()+i[1:]) #이해가 안감 모르겠음..
# Out:
# Dog
# Cat
# Parrot

# %%
#158
list_file=['hello.py','ex01.py','intro.hwp']
for i in range(len(list_file)):
  print(list_file[i].split('.')[0])
# Out:
# hello
# ex01
# intro

# %%
#159
listf=['intra.h','intra.c','define.h','run.py']

for i in range(len(listf)):
  if (listf[i].split('.')[1])=='h':
    print(listf[i])
# Out:
# intra.h
# define.h

# %%
#160
listf=['intra.h','intra.c','define.h','run.py']

for i in range(len(listf)):
  if (listf[i].split('.')[1])=='h':
    print(listf[i])
  elif (listf[i].split('.')[1])=='c':
    print(listf[i])
# Out:
# intra.h
# intra.c
# define.h
