# %%
#001
print("Hello World")
# Out:
# Hello World

# %%
#002
print("Mary's cometics")
# Out:
# Mary's cometics

# %%
#003
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
#004
print('"C:\windows"')
# Out:
# "C:\windows"

# %%
#005
print("안녕하세요.\n만나서\t\t반갑습니다.")

#\n은 줄바꿈을 의미하고 \t는 탭을 의미합니다.
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
#006
print("오늘은","일요일")
# Out:
# 오늘은 일요일

# %%
#007
print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
#008
print("naver/kakao/sk/samsung")
# Out:
# naver/kakao/sk/samsung

# %%
#009
print("first");print("second")
# Out:
# first
# second

# %%
#010
print(5/3)
# Out:
# 1.6666666666666667

# %%
#011
삼성전자=50000
평가금액 =삼성전자*10
print(평가금액)
# Out:
# 500000

# %%
#012
시가총액="298조"
현재가=50000
PER=15.79

# %%
#013
s="hello"
t="python"
print(s+"! "+t)
# Out:
# hello! python

# %%
#014
print("2 + 2 * 3 =", 2+2*3)
# Out:
# 2 + 2 * 3 = 8

# %%
#015
a=128
print(type(a))
a="132"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#016
number_str="720"
number_str=int(number_str)
print(type(number_str))
# Out:
# <class 'int'>

# %%
#017
num=100
num=str(num)
print(type(num))
# Out:
# <class 'str'>

# %%
#018
num="15.79"
num=float(num)
print(type(num))
# Out:
# <class 'float'>

# %%
#019
year="2020"
year=int(year)
print(year,year-1,year-2)
# Out:
# 2020 2019 2018

# %%
#020
monthprice=48584
month=36
total=monthprice*month
print(total)
# Out:
# 1749024
